# %% [markdown]
# Consider a list (list = []). You can perform the following commands:
#
# insert i e: Insert integer  at position .
# print: Print the list.
# remove e: Delete the first occurrence of integer .
# append e: Insert integer  at the end of the list.
# sort: Sort the list.
# pop: Pop the last element from the list.
# reverse: Reverse the list.
# Initialize your list and read in the value of  followed by  lines of commands where each command will be of the  types listed above. Iterate through each command in order and perform the corresponding operation on your list.
#
# Example
#
#
#
#
#
#
# : Append  to the list, .
# : Append  to the list, .
# : Insert  at index , .
# : Print the array.
# Output:
# [1, 3, 2]
# Input Format
#
# The first line contains an integer, , denoting the number of commands.
# Each line  of the  subsequent lines contains one of the commands described above.
#
# Constraints
#
# The elements added to the list must be integers.
# Output Format
#
# For each command of type print, print the list on a new line.
#
# Sample Input 0
#
# 12
# insert 0 5
# insert 1 10
# insert 0 6
# print
# remove 6
# append 9
# append 1
# sort
# print
# pop
# reverse
# print
# Sample Output 0
#
# [6, 5, 10]
# [1, 5, 9, 10]
# [9, 5, 1]

# %%
import urllib.request
if __name__ == '__main__':
    # 1. Replace this string with actual RAW GitHub URL
    url = "https://raw.githubusercontent.com/pravalika2318/basic-learning-of-python/main/input.txt"
    
    # 2. Fetch the text from Git and split it into a list of lines
    with urllib.request.urlopen(url) as response:
        git_inputs = response.read().decode('utf-8').splitlines()
    
    # 3. Create an iterator to mimic the input() function dynamically
    input_iterator = iter(git_inputs)
    def input(): return next(input_iterator)
    N = int(input())
    lst=[]
    for _ in range (N):
        command_args=input().split()
        cmd=command_args[0]
        if cmd =="insert":
            index=int(command_args[1])
            element=int(command_args[2])
            lst.insert(index,element)
        elif cmd == "print":
            print(lst)
        elif cmd=="remove":
            element=int(command_args[1])
            lst.remove(element)
        elif cmd== "append":
            element=int(command_args[1])
            lst.append(element)
        elif  cmd=="pop":
            lst.pop()   
        elif cmd=="sort":
            lst.sort() 
        elif cmd=="reverse":
            lst.reverse()
# Out:
# [6, 5, 10]
# [1, 5, 9, 10]
# [9, 5, 1]

# %% [markdown]
# Prev
# Next
# Tuple unpacking
#
# Tuple unpacking, also known as tuple destructuring, is a feature in Python that allows you to assign the elements of a tuple to individual variables in a single assignment statement.
# This makes it easy to extract and work with the individual elements of a tuple.
#
# Example
#
# my_tuple = (1, 'hello', 3.14)
#
# # Unpack the tuple into separate variables
# a, b, c = my_tuple
#
# # Print the unpacked variables
# print("a:", a)  # Output: a: 1
# print("b:", b)  # Output: b: hello
# print("c:", c)  # Output: c: 3.14
#
#
# Task
# We have defined a tuple for you in the IDE.
# Update the code to get the output as defined in the sample output below.
#
# Sample 1:
# Input
# Output
#
# Bob
# English
# 20
# Z

# %%
student = (["Alice", "Bob"], ["Math", "Science", "English"], 20, 'XYZ')

# Update the code below this line
a,b,c,d=student
print(a[1])
print(b[2])
print(c)
print(d[2])
# Out:
# Bob
# English
# 20
# Z

# %% [markdown]
# Task
# Given an integer, , and  space-separated integers as input, create a tuple, , of those  integers. Then compute and print the result of .
#
# Note: hash() is one of the functions in the __builtins__ module, so it need not be imported.
#
# Input Format
#
# The first line contains an integer, , denoting the number of elements in the tuple.
# The second line contains  space-separated integers describing the elements in tuple .
#
# Output Format
#
# Print the result of .
#
# Sample Input 0
#
# 2
# 1 2
# Sample Output 0
#
# 3713081631934410656 or -3550055125485641917

# %%
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    print (hash(tuple(integer_list)))#hash value varies for python versions
# Out:
# -3550055125485641917

# %% [markdown]
# """ searching : searching is the process of finding a specific elements in a collection(list,array,.....)"""
# [10,20,30,40,50] find 30: if thge element exists.
# returns its position (index)

# %% [markdown]
# Types of searching:
# 1.linear search:dont require sorting i.e unorederd
# 2.Binary search:sorting is needed(i.e ordered)

# %% [markdown]
# LINEAR SEARCH:
# it checks each elements one by one, so the list can be in any order.

# %%
numbers=[33,12,48,3,8,77]
key=int(input("enter the element:"))
for i in range (len(numbers)):
    if numbers[i]==key:
        print("index at:",i)
        break
# Out:
# index at: 1

# %%
key=int(input("enter the element:"))
if key in numbers:
    print("index at:",numbers.index(key))
else:
    print("element not found")
# Out:
# element not found

# %% [markdown]
# BINARY SEARCH:
# -------------------------------------------------------------------------
#
# binary search repeatedly dividesthe sorted list into 2 halfs .Until the element is found.
#
# NOTE:
# --------------------------------------------------------
#
# it worksonly on sorted data

# %%
numbers=[12,40,50,60,80]
key=int(input("enter the element:"))
low=0
high=len(numbers)-1
while low <=high:
    mid=low+high//2
    if numbers[mid]==key:
        print("index at:",mid)
        break
    elif numbers[mid]<key:
        low=mid+1
    else:
        high=mid-1
# Out:
# index at: 2

# %% [markdown]
# SORTING:
# ____________

# %% [markdown]
# arranging elements in order
#
# TYPES:
# ----------------------------------------------------------------------
#
# 1.BUBBLE SORT
# 2.SELECTION SORT
# 3.INSERTION SORT
# 4.QUICK SORT

# %% [markdown]
# BUBBLE SORT:
# _____________________
#
# it compares adjacent elements and swaps them if they are in the wrong order.
# After each pass/swap ,the largest element bubbles to the end . 5 2 4 1 -->5 2 --->swap
# 2 5 4 1 --> 5 4--> swap
# 2451 ---> 5 1 ->swap
# 2 4 1 5--> 2 4--> 2 1-->swap 1 4 2 5 ----> 4 2 swap--> 1 2 4 5

# %%
a = []

n = int(input("Enter no of elements: "))

for i in range(n):
    a.append(int(input("Enter element: ")))

for i in range(len(a)-1):
    swapped = False
    for j in range(len(a)-1-i):
        if a[j] > a[j+1]:
            a[j], a[j+1] = a[j+1], a[j]
        

print("Sorted list:", a)
# Out:
# Sorted list: [5, 17, 90, 99]

# %%
a=[3,4,9,1,2,10]
for i in range (len(a)):
    for j in range(len(a)-1):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
print(a)
key=int(input("enter the element:"))
low=0
high=len(a)-1
while low <=high:
    mid=low+(high-low)//2
    if a[mid]==key:
        print("index at:",mid)
        break
    elif a[mid]<key:
        low=mid+1
    else:
        high=mid-1
else:
    print("element not found")
# Out:
# [1, 2, 3, 4, 9, 10]
# index at: 5
